# %%
import pandas as pd
import seaborn as sns

from keys import db2

# %%
chicago_education_data = pd.read_csv('https://data.cityofchicago.org/resource/9xs2-f89t.csv')

# %%
# %load_ext sql
# %config SqlMagic.displaycon = False

conn_string = 'ibm_db_sa://{username}:{password}@{hostname}:{port}/{database}?security=SSL'.format(
    **db2
)

# %sql {conn_string}

# %%
# %sql --persist chicago_education_data
# Out:
# 'Persisted chicago_education_data'

# %%
# Get Table Info
query = 'select TABSCHEMA, TABNAME, CREATE_TIME from syscat.tables where tabschema=UCASE(\'{username}\')'.format(
    **db2)
# %sql {query}
# Out:
# Done.
# [('DSB84911', 'EMPLOYEES', datetime.datetime(2022, 2, 1, 13, 2, 25, 663181)),
#  ('DSB84911', 'JOB_HISTORY', datetime.datetime(2022, 2, 1, 13, 2, 25, 845909)),
#  ('DSB84911', 'JOBS', datetime.datetime(2022, 2, 1, 13, 2, 25, 988178)),
#  ('DSB84911', 'DEPARTMENTS', datetime.datetime(2022, 2, 1, 13, 2, 26, 118199)),
#  ('DSB84911', 'LOCATIONS', datetime.datetime(2022, 2, 1, 13, 2, 26, 243965)),
#  ('DSB84911', 'PETRESCUE', datetime.datetime(2022, 2, 7, 10, 27, 56, 516664)),
#  ('DSB84911', 'INSTRUCTOR', datetime.datetime(2022, 2, 7, 13, 48, 3, 878814)),
#  ('DSB84911', 'INTERNATIONAL_STUDENT_TEST_SCORES', datetime.datetime(2022, 2, 7, 15, 0, 5, 609752)),
#  ('DSB84911', 'CHICAGO_SOCIOECONOMIC_DATA', datetime.datetime(2022, 2, 8, 12, 26, 44, 740479)),
#  ('DSB84911', 'CHICAGO_EDUCATION_DATA', datetime.datetime(2022, 2, 8, 14, 15, 51, 848934))]

# %%
# %sql select count(*) from SYSCAT.COLUMNS where TABNAME = 'CHICAGO_EDUCATION_DATA'
# Out:
# Done.
# [(80,)]

# %%
# Get Column Info
# %sql select COLNAME, TYPENAME, LENGTH from SYSCAT.COLUMNS where TABNAME = 'CHICAGO_EDUCATION_DATA'
# Out:
# Done.
# [('STATE', 'CLOB', 1048576),
#  ('ZIP_CODE', 'BIGINT', 8),
#  ('PHONE_NUMBER', 'CLOB', 1048576),
#  ('LINK_', 'CLOB', 1048576),
#  ('NETWORK_MANAGER', 'CLOB', 1048576),
#  ('COLLABORATIVE_NAME', 'CLOB', 1048576),
#  ('ADEQUATE_YEARLY_PROGRESS_MADE_', 'CLOB', 1048576),
#  ('TRACK_SCHEDULE', 'CLOB', 1048576),
#  ('CPS_PERFORMANCE_POLICY_STATUS', 'CLOB', 1048576),
#  ('CPS_PERFORMANCE_POLICY_LEVEL', 'CLOB', 1048576),
#  ('HEALTHY_SCHOOLS_CERTIFIED_', 'CLOB', 1048576),
#  ('SAFETY_ICON_', 'CLOB', 1048576),
#  ('SAFETY_SCORE', 'DOUBLE', 8),
#  ('FAMILY_INVOLVEMENT_ICON', 'CLOB', 1048576),
#  ('FAMILY_INVOLVEMENT_SCORE', 'CLOB', 1048576),
#  ('index', 'BIGINT', 8),
#  ('SCHOOL_ID', 'BIGINT', 8),
#  ('NAME_OF_SCHOOL', 'CLOB', 1048576),
#  ('ELEMENTARY_OR_HIGH_SCHOOL', 'CLOB', 1048576),
#  ('STREET_ADDRESS', 'CLOB', 1048576),
#  ('CITY', 'CLOB', 1048576),
#  ('ENVIRONMENT_ICON_', 'CLOB', 1048576),
#  ('ENVIRONMENT_SCORE', 'DOUBLE', 8),
#  ('INSTRUCTION_ICON_', 'CLOB', 1048576),
# ...

# %%
# %sql select count(ELEMENTARY_OR_HIGH_SCHOOL) from CHICAGO_EDUCATION_DATA where ELEMENTARY_OR_HIGH_SCHOOL = 'ES'
# Out:
# Done.
# [(462,)]

# %%
# %sql select SAFETY_SCORE from CHICAGO_EDUCATION_DATA order by SAFETY_SCORE desc nulls last limit 5
# Out:
# Done.
# [(99.0,), (99.0,), (99.0,), (99.0,), (99.0,)]

# %%
# %sql select NAME_OF_SCHOOL from CHICAGO_EDUCATION_DATA where SAFETY_SCORE = (select MAX(Safety_Score) from CHICAGO_EDUCATION_DATA)
# Out:
# Done.
# [('Abraham Lincoln Elementary School',),
#  ('Alexander Graham Bell Elementary School',),
#  ('Annie Keller Elementary Gifted Magnet School',),
#  ('Augustus H Burley Elementary School',),
#  ('Edgar Allan Poe Elementary Classical School',),
#  ('Edgebrook Elementary School',),
#  ('Ellen Mitchell Elementary School',),
#  ('James E McDade Elementary Classical School',),
#  ('James G Blaine Elementary School',),
#  ('LaSalle Elementary Language Academy',),
#  ('Mary E Courtenay Elementary Language Arts Center',),
#  ('Northside College Preparatory High School',),
#  ('Northside Learning Center High School',),
#  ('Norwood Park Elementary School',),
#  ('Oriole Park Elementary School',),
#  ('Sauganash Elementary School',),
#  ('Stephen Decatur Classical Elementary School',),
#  ('Talman Elementary School',),
#  ('Wildwood Elementary School',)]

# %%
# %sql select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE from CHICAGO_EDUCATION_DATA order by AVERAGE_STUDENT_ATTENDANCE nulls last limit 5
# Out:
# Done.
# [('Richard T Crane Technical Preparatory High School', 57.9),
#  ('Barbara Vick Early Childhood & Family Center', 60.9),
#  ('Dyett High School', 62.5),
#  ('Wendell Phillips Academy High School', 63.0),
#  ('Orr Academy High School', 66.3)]
