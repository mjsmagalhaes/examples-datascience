# %% [markdown]
# # Data Analysis with Python
#
# Created as part of the corse *Data Analysis with Python* from IBM @ Coursera.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 

from icecream import ic
from scipy import stats
from click import style
from dslib.analysis import Analysis
from dslib.helpers import replace_csv_header
from dslib.missing import list_missing_values
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ## Importing Data

# %% [markdown]
# This database comes with 2 files: imports-85.data and imports-85.names. The former contains the data itself while the latter the description of data. From that description I've created imports-85.headers with column names to create the csv file with the usual header.

# %%
# Create CSV file with header from file
replace_csv_header('data/imports-85.data', 'data/imports-85.header')

# %% [markdown]
# Loading the csv file created above

# %%
df = pd.read_csv('data/imports-85.csv')

# %%
# remove first column (a duplicated index)
df.drop(
  columns=df.columns[0],
  axis='columns',
  inplace=True
)

# %% [markdown]
# ### Missing Values

# %%
list_missing_values(df)
# Out:
# normalized-losses: 41 missing values of type object
# num-of-doors: 2 missing values of type object
# bore: 4 missing values of type object
# stroke: 4 missing values of type object
# horsepower: 2 missing values of type object
# peak-rpm: 2 missing values of type object
# price: 4 missing values of type object

# %% [markdown]
# #### Replace Missing Data with the Average

# %%
def replace_nan_by_mean(column):
  """
  Replace NAs with the mean of the column over the entire dataset.
  """
  avg_col = column.astype("float").mean(axis=0)
  print("Average of {0}:".format(column.name), avg_col)
  return column.replace(np.nan, avg_col, inplace=True)


replace_nan_by_mean(df["normalized-losses"])
replace_nan_by_mean(df["stroke"])
replace_nan_by_mean(df["bore"])
replace_nan_by_mean(df["horsepower"])
replace_nan_by_mean(df["peak-rpm"])
# Out:
# Average of normalized-losses: 122.0
# Average of stroke: 3.255422885572139
# Average of bore: 3.3297512437810943
# Average of horsepower: 104.25615763546799
# Average of peak-rpm: 5125.369458128079

# %% [markdown]
# #### Replace Missing Data with the Most Frequent

# %%
def replace_nan_by_frequency(column):
  """
  Replace NAs with the mean of the column over the entire dataset.
  """
  mode_col = column.value_counts().idxmax()
  print("Most Frequent Value of {0}:".format(column.name), mode_col)

  column.replace(np.nan, mode_col, inplace=True)
  return column

replace_nan_by_frequency(df['num-of-doors']);
# Out:
# Most Frequent Value of num-of-doors: four

# %% [markdown]
# #### "Handling" Missing Values by Droping the line

# %%
df.dropna(subset=['price'], axis=0, inplace=True)

# %% [markdown]
# ### Convert Types and Format

# %%
to_float = ["bore", "stroke", "price", "peak-rpm"]
df[to_float] = df[to_float].astype("float")

to_int = ["normalized-losses", 'horsepower']
df[to_int] = df[to_int].astype("int")
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int32
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
#  16  engine-size        201 non-null    int64
#  17  fuel-system        201 non-null    object
#  18  bore               201 non-null    float64
#  19  stroke             201 non-null    float64
#  20  compression-ratio  201 non-null    float64
#  21  horsepower         201 non-null    int32
#  22  peak-rpm           201 non-null    float64
#  23  city-mpg           201 non-null    int64
#  24  highway-mpg        201 non-null    int64
#  25  price              201 non-null    float64
# dtypes: float64(9), int32(2), int64(5), object(10)
# memory usage: 40.8+ KB

# %%
df['fuel-type'].value_counts()
d = pd.get_dummies(df['fuel-type'])

d.rename(
    columns={'gas': 'fuel-type-gas', 'diesel': 'fuel-type-diesel'}, 
    inplace=True
)

# merge the new dataframe to the original dataframe
pd.concat([df, d], axis=1).drop('fuel-type', axis=1)
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 200         -1                 95        volvo        std         four
# 201         -1                 95        volvo      turbo         four
# 202         -1                 95        volvo        std         four
# 203         -1                 95        volvo      turbo         four
# 204         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base  length  ...  bore  \
# 0    convertible          rwd           front        88.6   168.8  ...  3.47
# 1    convertible          rwd           front        88.6   168.8  ...  3.47
# 2      hatchback          rwd           front        94.5   171.2  ...  2.68
# 3          sedan          fwd           front        99.8   176.6  ...  3.19
# 4          sedan          4wd           front        99.4   176.6  ...  3.19
# ..           ...          ...             ...         ...     ...  ...   ...
# 200        sedan          rwd           front       109.1   188.8  ...  3.78
# 201        sedan          rwd           front       109.1   188.8  ...  3.78
# 202        sedan          rwd           front       109.1   188.8  ...  3.58
# 203        sedan          rwd           front       109.1   188.8  ...  3.01
# 204        sedan          rwd           front       109.1   188.8  ...  3.78
#
#      stroke  compression-ratio horsepower peak-rpm  city-mpg highway-mpg  \
# 0      2.68                9.0        111   5000.0        21          27
# 1      2.68                9.0        111   5000.0        21          27
# 2      3.47                9.0        154   5000.0        19          26
# 3      3.40               10.0        102   5500.0        24          30
# 4      3.40                8.0        115   5500.0        18          22
# ..      ...                ...        ...      ...       ...         ...
# 200    3.15                9.5        114   5400.0        23          28
# 201    3.15                8.7        160   5300.0        19          25
# 202    2.87                8.8        134   5500.0        18          23
# 203    3.40               23.0        106   4800.0        26          27
# 204    3.15                9.5        114   5400.0        19          25
#
#        price  fuel-type-diesel  fuel-type-gas
# 0    13495.0                 0              1
# 1    16500.0                 0              1
# 2    16500.0                 0              1
# 3    13950.0                 0              1
# 4    17450.0                 0              1
# ..       ...               ...            ...
# 200  16845.0                 0              1
# 201  19045.0                 0              1
# 202  21485.0                 0              1
# 203  22470.0                 1              0
# 204  22625.0                 0              1
#
# [201 rows x 27 columns]

# %%
sns.boxplot(y="price", x='num-of-doors', data=df)
# Out:
# <AxesSubplot:xlabel='num-of-doors', ylabel='price'>

# %%
sns.jointplot(x='engine-size', y='price', data=df)

# %%
df[['price', 'drive-wheels', 'body-style']].groupby(['drive-wheels', 'body-style'], as_index=False).mean().pivot(
    index='drive-wheels',
    columns='body-style'
)
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
lab=Analysis(df)

# %%
lab.eda.corr(df)
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008153           0.055045    0.158018  0.123952
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075810           0.217300    0.371178  0.579795
# peak-rpm            0.279740           0.239543   -0.360305 -0.285970
# city-mpg           -0.035527          -0.225016   -0.470606 -0.665192
# highway-mpg         0.036233          -0.181877   -0.543304 -0.698142
# price              -0.082391           0.133999    0.584642  0.690628
#
#                       width    height  curb-weight  engine-size      bore  \
# symboling         -0.242423 -0.550160    -0.233118    -0.110581 -0.140019
# normalized-losses  0.086802 -0.373737     0.099404     0.112360 -0.029862
# wheel-base         0.814507  0.590742     0.782097     0.572027  0.493244
# length             0.857170  0.492063     0.880665     0.685025  0.608971
# width              1.000000  0.306002     0.866201     0.729436  0.544885
# height             0.306002  1.000000     0.307581     0.074694  0.180449
# curb-weight        0.866201  0.307581     1.000000     0.849072  0.644060
# engine-size        0.729436  0.074694     0.849072     1.000000  0.572609
# bore               0.544885  0.180449     0.644060     0.572609  1.000000
# stroke             0.188822 -0.060663     0.167438     0.205928 -0.055390
# compression-ratio  0.189867  0.259737     0.156433     0.028889  0.001263
# horsepower         0.615056 -0.087001     0.757981     0.822668  0.566903
# peak-rpm          -0.245800 -0.309974    -0.279361    -0.256733 -0.267392
# city-mpg          -0.633531 -0.049800    -0.749543    -0.650546 -0.582027
# highway-mpg       -0.680635 -0.104812    -0.794889    -0.679571 -0.591309
# price              0.751265  0.135486     0.834415     0.872335  0.543155
#
#                      stroke  compression-ratio  horsepower  peak-rpm  \
# symboling         -0.008153          -0.182196    0.075810  0.279740
# normalized-losses  0.055045          -0.114713    0.217300  0.239543
# wheel-base         0.158018           0.250313    0.371178 -0.360305
# length             0.123952           0.159733    0.579795 -0.285970
# width              0.188822           0.189867    0.615056 -0.245800
# height            -0.060663           0.259737   -0.087001 -0.309974
# curb-weight        0.167438           0.156433    0.757981 -0.279361
# engine-size        0.205928           0.028889    0.822668 -0.256733
# bore              -0.055390           0.001263    0.566903 -0.267392
# stroke             1.000000           0.187871    0.098128 -0.063561
# compression-ratio  0.187871           1.000000   -0.214489 -0.435780
# horsepower         0.098128          -0.214489    1.000000  0.107884
# peak-rpm          -0.063561          -0.435780    0.107884  1.000000
# city-mpg          -0.033956           0.331425   -0.822192 -0.115413
# highway-mpg       -0.034636           0.268465   -0.804579 -0.058598
# price              0.082269           0.071107    0.809607 -0.101616
#
#                    city-mpg  highway-mpg     price
# symboling         -0.035527     0.036233 -0.082391
# normalized-losses -0.225016    -0.181877  0.133999
# wheel-base        -0.470606    -0.543304  0.584642
# length            -0.665192    -0.698142  0.690628
# width             -0.633531    -0.680635  0.751265
# height            -0.049800    -0.104812  0.135486
# curb-weight       -0.749543    -0.794889  0.834415
# engine-size       -0.650546    -0.679571  0.872335
# bore              -0.582027    -0.591309  0.543155
# stroke            -0.033956    -0.034636  0.082269
# compression-ratio  0.331425     0.268465  0.071107
# horsepower        -0.822192    -0.804579  0.809607
# peak-rpm          -0.115413    -0.058598 -0.101616
# city-mpg           1.000000     0.972044 -0.686571
# highway-mpg        0.972044     1.000000 -0.704692
# price             -0.686571    -0.704692  1.000000

# %%
sns.regplot(x="engine-size", y="price", data=df);
plt.ylim(0,);

# %%
df.describe(include=['object'])
# Out:
#           make fuel-type aspiration num-of-doors body-style drive-wheels  \
# count      201       201        201          201        201          201
# unique      22         2          2            2          5            3
# top     toyota       gas        std         four      sedan          fwd
# freq        32       181        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92

# %%
# engine-location as variable
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(
    columns={'engine-location': 'value_counts'}, inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts.head(10)
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %%
engine_loc_counts
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %%
def list_relevant_vars(df) -> list:
  var_list = []
  for c in df:
    if c == 'price':
      continue
    
    if df[c].dtype != 'object':
      pearson_coef, p_value = stats.pearsonr(df[c], df['price']);
      msg = '{0:15s}: R={1:.3f} (p:{2:.2g})'.format(c, pearson_coef, p_value)
      color = 'green'
    else:
      # print('{0:15s}: ----'.format(c))
      grp = df[[c, 'price']].groupby([c])
      v = list(map(lambda k: grp.get_group(k)['price'], grp.groups))
      r = stats.f_oneway(*v)
      p_value = r.pvalue
      msg = '{0:15s}: F={1:.3f} (p:{2:.2g})'.format(c, r.statistic, r.pvalue)
      color = 'yellow'
    
    if p_value < 0.001:
      msg = style(msg, fg=color)
      var_list.append(c)
    
    print(msg)
  return var_list

list_relevant_vars(df)
# Out:
# symboling      : R=-0.082 (p:0.24)
# normalized-losses: R=0.134 (p:0.058)
# make           : F=33.232 (p:1.1e-50)
# fuel-type      : F=2.452 (p:0.12)
# aspiration     : F=6.631 (p:0.011)
# num-of-doors   : F=0.359 (p:0.55)
# body-style     : F=9.129 (p:8.8e-07)
# drive-wheels   : F=67.954 (p:3.4e-23)
# engine-location: F=24.496 (p:1.6e-06)
# wheel-base     : R=0.585 (p:8.1e-20)
# length         : R=0.691 (p:8e-30)
# width          : R=0.751 (p:9.2e-38)
# height         : R=0.135 (p:0.055)
# curb-weight    : R=0.834 (p:2.2e-53)
# engine-type    : F=9.845 (p:2.1e-08)
# num-of-cylinders: F=54.944 (p:2.9e-39)
# engine-size    : R=0.872 (p:9.3e-64)
# fuel-system    : F=15.024 (p:1.3e-15)
# bore           : R=0.543 (p:8e-17)
# stroke         : R=0.082 (p:0.25)
# compression-ratio: R=0.071 (p:0.32)
# horsepower     : R=0.810 (p:6.3e-48)
# peak-rpm       : R=-0.102 (p:0.15)
# city-mpg       : R=-0.687 (p:2.3e-29)
# highway-mpg    : R=-0.705 (p:1.7e-31)
# ['make',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'horsepower',
#  'city-mpg',
#  'highway-mpg']

# %%
# import statsmodels.api as sm
# from statsmodels.formula.api import ols
# res = ols('price ~ C(drive_wheels)', data=df).fit()
# res.summary()

# %%
df.rename(columns={'drive-wheels':'drive_wheels'}, inplace=True)

# %%
from itertools import combinations
c = 'make'
grp = df[[c, 'price']].groupby([c])
pairwise = list(combinations(grp.groups, 2))
result = map(
    lambda p: [
        p[0], 
        p[1], 
        stats.f_oneway(
            grp.get_group(p[0])['price'], 
            grp.get_group(p[1])['price']
        ).pvalue],
    pairwise
)

r = pd.DataFrame(result).pivot(
    index=1,
    columns=0
).style.format('{:.2g}', na_rep='---').applymap(lambda x: 'color: royalblue;' if x < 0.001 and x > 0 else None)
r
# sns.heatmap(r)

# for pair in pairwise:
#   # v = list(map(lambda k: grp.get_group(k)['price'], grp.groups))
#   r = stats.f_oneway(grp.get_group(pair[0])['price'], grp.get_group(pair[1])['price'])
#   color = 'green' if r.pvalue < 0.001 else 'white'
#   print(style(
#     '{0:25s}: F={1:.3f} (p:{2:.2g})'.format('{0}+{1}'.format(*pair), r.statistic, r.pvalue),
#     fg=color
#   ))
# Out:
# <style type="text/css">
# #T_c9da6_row2_col0, #T_c9da6_row2_col1, #T_c9da6_row3_col0, #T_c9da6_row3_col1, #T_c9da6_row3_col2, #T_c9da6_row4_col0, #T_c9da6_row4_col1, #T_c9da6_row4_col2, #T_c9da6_row6_col0, #T_c9da6_row6_col1, #T_c9da6_row6_col3, #T_c9da6_row6_col4, #T_c9da6_row6_col5, #T_c9da6_row7_col1, #T_c9da6_row7_col2, #T_c9da6_row7_col7, #T_c9da6_row8_col1, #T_c9da6_row8_col3, #T_c9da6_row8_col4, #T_c9da6_row8_col5, #T_c9da6_row8_col8, #T_c9da6_row10_col1, #T_c9da6_row10_col2, #T_c9da6_row10_col7, #T_c9da6_row10_col9, #T_c9da6_row11_col2, #T_c9da6_row11_col7, #T_c9da6_row11_col9, #T_c9da6_row12_col3, #T_c9da6_row12_col4, #T_c9da6_row12_col5, #T_c9da6_row12_col7, #T_c9da6_row12_col9, #T_c9da6_row12_col11, #T_c9da6_row13_col1, #T_c9da6_row13_col2, #T_c9da6_row13_col7, #T_c9da6_row13_col9, #T_c9da6_row13_col13, #T_c9da6_row14_col4, #T_c9da6_row14_col5, #T_c9da6_row14_col8, #T_c9da6_row14_col11, #T_c9da6_row14_col12, #T_c9da6_row14_col13, #T_c9da6_row14_col14, #T_c9da6_row15_col7, #T_c9da6_row16_col4, #T_c9da6_row16_col5, #T_c9da6_row16_col7, #T_c9da6_row16_col9, #T_c9da6_row16_col11, #T_c9da6_row16_col14, #T_c9da6_row16_col15, #T_c9da6_row17_col0, #T_c9da6_row17_col1, #T_c9da6_row17_col2, #T_c9da6_row17_col7, #T_c9da6_row17_col9, #T_c9da6_row17_col13, #T_c9da6_row17_col15, #T_c9da6_row17_col17, #T_c9da6_row18_col1, #T_c9da6_row18_col2, #T_c9da6_row18_col7, #T_c9da6_row18_col9, #T_c9da6_row18_col13, #T_c9da6_row18_col15, #T_c9da6_row18_col17, #T_c9da6_row19_col1, #T_c9da6_row19_col2, #T_c9da6_row19_col7, #T_c9da6_row19_col9, #T_c9da6_row19_col13, #T_c9da6_row19_col15, #T_c9da6_row19_col17, #T_c9da6_row20_col3, #T_c9da6_row20_col4, #T_c9da6_row20_col5, #T_c9da6_row20_col7, #T_c9da6_row20_col8, #T_c9da6_row20_col9, #T_c9da6_row20_col11, #T_c9da6_row20_col12, #T_c9da6_row20_col14, #T_c9da6_row20_col15, #T_c9da6_row20_col18, #T_c9da6_row20_col19, #T_c9da6_row20_col20 {
#   color: royalblue;
# }
# </style>
# <table id="T_c9da6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" colspan="21">2</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >0</th>
#       <th class="col_heading level1 col0" >alfa-romero</th>
#       <th class="col_heading level1 col1" >audi</th>
#       <th class="col_heading level1 col2" >bmw</th>
#       <th class="col_heading level1 col3" >chevrolet</th>
#       <th class="col_heading level1 col4" >dodge</th>
#       <th class="col_heading level1 col5" >honda</th>
#       <th class="col_heading level1 col6" >isuzu</th>
#       <th class="col_heading level1 col7" >jaguar</th>
#       <th class="col_heading level1 col8" >mazda</th>
#       <th class="col_heading level1 col9" >mercedes-benz</th>
#       <th class="col_heading level1 col10" >mercury</th>
#       <th class="col_heading level1 col11" >mitsubishi</th>
#       <th class="col_heading level1 col12" >nissan</th>
#       <th class="col_heading level1 col13" >peugot</th>
#       <th class="col_heading level1 col14" >plymouth</th>
#       <th class="col_heading level1 col15" >porsche</th>
#       <th class="col_heading level1 col16" >renault</th>
#       <th class="col_heading level1 col17" >saab</th>
#       <th class="col_heading level1 col18" >subaru</th>
#       <th class="col_heading level1 col19" >toyota</th>
#       <th class="col_heading level1 col20" >volkswagen</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >1</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9da6_level0_row0" class="row_heading level0 row0" >audi</th>
#       <td id="T_c9da6_row0_col0" class="data row0 col0" >0.31</td>
#       <td id="T_c9da6_row0_col1" class="data row0 col1" >---</td>
#       <td id="T_c9da6_row0_col2" class="data row0 col2" >---</td>
#       <td id="T_c9da6_row0_col3" class="data row0 col3" >---</td>
#       <td id="T_c9da6_row0_col4" class="data row0 col4" >---</td>
#       <td id="T_c9da6_row0_col5" class="data row0 col5" >---</td>
#       <td id="T_c9da6_row0_col6" class="data row0 col6" >---</td>
#       <td id="T_c9da6_row0_col7" class="data row0 col7" >---</td>
#       <td id="T_c9da6_row0_col8" class="data row0 col8" >---</td>
#       <td id="T_c9da6_row0_col9" class="data row0 col9" >---</td>
#       <td id="T_c9da6_row0_col10" class="data row0 col10" >---</td>
#       <td id="T_c9da6_row0_col11" class="data row0 col11" >---</td>
#       <td id="T_c9da6_row0_col12" class="data row0 col12" >---</td>
#       <td id="T_c9da6_row0_col13" class="data row0 col13" >---</td>
#       <td id="T_c9da6_row0_col14" class="data row0 col14" >---</td>
#       <td id="T_c9da6_row0_col15" class="data row0 col15" >---</td>
#       <td id="T_c9da6_row0_col16" class="data row0 col16" >---</td>
#       <td id="T_c9da6_row0_col17" class="data row0 col17" >---</td>
#       <td id="T_c9da6_row0_col18" class="data row0 col18" >---</td>
#       <td id="T_c9da6_row0_col19" class="data row0 col19" >---</td>
#       <td id="T_c9da6_row0_col20" class="data row0 col20" >---</td>
#     </tr>
#     <tr>
#       <th id="T_c9da6_level0_row1" class="row_heading level0 row1" >bmw</th>
#       <td id="T_c9da6_row1_col0" class="data row1 col0" >0.088</td>
#       <td id="T_c9da6_row1_col1" class="data row1 col1" >0.062</td>
#       <td id="T_c9da6_row1_col2" class="data row1 col2" >---</td>
#       <td id="T_c9da6_row1_col3" class="data row1 col3" >---</td>
#       <td id="T_c9da6_row1_col4" class="data row1 col4" >---</td>
#       <td id="T_c9da6_row1_col5" class="data row1 col5" >---</td>
#       <td id="T_c9da6_row1_col6" class="data row1 col6" >---</td>
#       <td id="T_c9da6_row1_col7" class="data row1 col7" >---</td>
#       <td id="T_c9da6_row1_col8" class="data row1 col8" >---</td>
#       <td id="T_c9da6_row1_col9" class="data row1 col9" >---</td>
#       <td id="T_c9da6_row1_col10" class="data row1 col10" >---</td>
#       <td id="T_c9da6_row1_col11" class="data row1 col11" >---</td>
#       <td id="T_c9da6_row1_col12" class="data row1 col12" >---</td>
#       <td id="T_c9da6_row1_col13" class="data row1 col13" >---</td>
#       <td id="T_c9da6_row1_col14" class="data row1 col14" >---</td>
#       <td id="T_c9da6_row1_col15" class="data row1 col15" >---</td>
#       <td id="T_c9da6_row1_col16" class="data row1 col16" >---</td>
#       <td id="T_c9da6_row1_col17" class="data row1 col17" >---</td>
#       <td id="T_c9da6_row1_col18" class="data row1 col18" >---</td>
#       <td id="T_c9da6_row1_col19" class="data row1 col19" >---</td>
#       <td id="T_c9da6_row1_col20" class="data row1 col20" >---</td>
#     </tr>
#     <tr>
#       <th id="T_c9da6_level0_row2" class="row_heading level0 row2" >chevrolet</th>
#       <td id="T_c9da6_row2_col0" class="data row2 col0" >0.00097</td>
#       <td id="T_c9da6_row2_col1" class="data row2 col1" >0.00074</td>
#       <td id="T_c9da6_row2_col2" class="data row2 col2" >0.0055</td>
#       <td id="T_c9da6_row2_col3" class="data row2 col3" >---</td>
#       <td id="T_c9da6_row2_col4" class="data row2 col4" >---</td>
#       <td id="T_c9da6_row2_col5" class="data row2 col5" >---</td>
#       <td id="T_c9da6_row2_col6" class="data row2 col6" >---</td>
#       <td id="T_c9da6_row2_col7" class="data row2 col7" >---</td>
#       <td id="T_c9da6_row2_col8" class="data r

# %%
list(grp.groups.keys())
# Out:
# ['convertible', 'hardtop', 'hatchback', 'sedan', 'wagon']
